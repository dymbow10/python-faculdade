# %%
import pandas as pd
df = pd.read_csv("houses_to_rent.csv", encoding = "utf-8")

# %%
#vetores logicos no loc
df.loc[[True, False, True], [True, False, True]]
# Out:
#    Unnamed: 0  area
# 0           0   240
# 2           2   443

# %%
#como o pandas realiza opercaçoes logicas no dataframe
df.animal == "acept"
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
# 3           3     1    73      2         2               1    12  acept
# 5           5     1    13      1         1               0     2  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 5  not furnished      R$0     R$2,200         R$42           R$28   R$2,270

# %%
#usando o resultado para filtrar dados
df[df.animal == "acept"].head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
# 3           3     1    73      2         2               1    12  acept
# 5           5     1    13      1         1               0     2  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 5  not furnished      R$0     R$2,200         R$42           R$28   R$2,270

# %%
#and (&) e or (|)
df[(df.animal == "acept") | (df.furniture == "furnished")].head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor animal  \
# 0           0     1   240      3         3               4     -  acept
# 1           1     0    64      2         1               1    10  acept
# 2           2     1   443      5         5               4     3  acept
# 3           3     1    73      2         2               1    12  acept
# 5           5     1    13      1         1               0     2  acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 5  not furnished      R$0     R$2,200         R$42           R$28   R$2,270

# %%
df[(df.animal == "acept") & (df.furniture == "furnished")][["hoa", "rent amount"]].head()
# Out:
#         hoa rent amount
# 0       R$0     R$8,000
# 2   R$4,172     R$7,000
# 6   R$1,950     R$5,000
# 8     R$828     R$2,000
# 11    R$406     R$1,550

# %%
df.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257
