# %%
import pandas as pd

# %%
dados = pd.read_excel("houses_to_rent.xlsx")

# %%
dados.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257

# %%
#selecionando uma ou n colunas por indice
dados["furniture"].head()
# Out:
# 0        furnished
# 1    not furnished
# 2        furnished
# 3    not furnished
# 4    not furnished
# Name: furniture, dtype: object

# %%
dados[["animal","furniture"]].head()
# Out:
#       animal      furniture
# 0      acept      furnished
# 1      acept  not furnished
# 2      acept      furnished
# 3      acept  not furnished
# 4  not acept  not furnished

# %%
#selecionando por notação de ponto (tem que ser um nome de coluna)
dados.floor.head()
# Out:
# 0     -
# 1    10
# 2     3
# 3    12
# 4     -
# Name: floor, dtype: object

# %%
#adicionando coluna nova
dados["rooms_bathroom"] = dados["rooms"] + dados["bathroom"]

# %%
dados.head()
# Out:
#    Unnamed: 0  city  area  rooms  bathroom  parking spaces floor     animal  \
# 0           0     1   240      3         3               4     -      acept
# 1           1     0    64      2         1               1    10      acept
# 2           2     1   443      5         5               4     3      acept
# 3           3     1    73      2         2               1    12      acept
# 4           4     1    19      1         1               0     -  not acept
#
#        furniture      hoa rent amount property tax fire insurance     total  \
# 0      furnished      R$0     R$8,000      R$1,000          R$121   R$9,121
# 1  not furnished    R$540       R$820        R$122           R$11   R$1,493
# 2      furnished  R$4,172     R$7,000      R$1,417           R$89  R$12,680
# 3  not furnished    R$700     R$1,250        R$150           R$16   R$2,116
# 4  not furnished      R$0     R$1,200         R$41           R$16   R$1,257
#
#    rooms_bathroom
# 0               6
# ...
